# %%
import sqlite3
import getpass
import time
import math

db=sqlite3.connect('SUMTDB.sqlite')
dbh=db.cursor()

na=' '

dbh.executescript('''
CREATE TABLE IF NOT EXISTS movie(
scre INTEGER UNIQUE,
seu INTEGER,
mona TEXT NOT NULL,
noot INTEGER,
price REAL);

CREATE TABLE IF NOT EXISTS account(
una TEXT NO NULL UNIQUE ,
pd TEXT);

CREATE TABLE IF NOT EXISTS bill(
usna TEXT,
movna TEXT,
noti INTEGER,
screno INTEGER)
''') 

def clrscr():
    print( "\n" * 100 )

def movshow(l):
    print('{:<10}'.format('SCREEN NO'),'|','{:<25}'.format('MOVIE NAME'),'|','{:<15}'.format('NO OF TICKETS'),'|','{:<10}'.format('SEATS USED'),'|','{:<10}'.format('PRICE'))
    for i in l:
        print('{:<10}'.format(i[0]),'|','{:<25}'.format(i[2]),'|','{:<15}'.format(i[3]),'|','{:<10}'.format(i[1]),'|','{:<10}'.format(i[4]))
        time.sleep(2)
    enter=input('PRESS ENTER TO CONTINUE!!')
        
def newuser():
    clrscr()
    print('\t\tS.U. MOVIE THEATRE WELCOMES YOU!!!')
    print(chr(12)*80)
    u=input('ENTER USERNAME:')
    p=input('ENTER PASSWORD:')
    try:
        dbh.execute('INSERT INTO account(una,pd) VALUES (?,?)',(u,p))
        db.commit()
        print("YOUR ACCOUNT HAS BEEN CREATED, SO KINDLY LOGIN IN FRONT PAGE")
        enter=input('PRESS ENTER TO CONTINUE!!')
    except:
        print('USERNAME ALREADY EXISTS!!!!')
        enter=input('PRESS ENTER TO CONTINUE!!')
        newuser()

def acclist():
    clrscr()
    print('\t\tS.U. MOVIE THEATRE WELCOMES YOU!!!')
    print(chr(12)*80)   
    dbh.execute('SELECT * FROM account')
    r=dbh.fetchall()
    print('USERNAMES')
    for i in r:
        print(i[0])
        time.sleep(2)
    enter=input('PRESS ENTER TO CONTINUE!!')

def delacc():
    clrscr()
    acclist()
    h=input('ENTER ACCOUNT USERNAME TO BE DELETED:')
    try:
        dbh.execute('SELECT * FROM account WHERE una=?',(h,))
        check=dbh.fetchone()[0]
        dbh.execute('DELETE FROM account WHERE una=?',(h,))
        db.commit()
        print('ACOUNT DELETED SUCCESSFULLY!!!!')
        enter=input('PRESS ENTER TO CONTINUE!!')
    except:
        print('NO SUCH USER AVAILABLE!!!!!')
        enter=input('PRESS ENTER TO CONTINUE!!')

def intro(): 
    clrscr()
    print("\n"*5)
    print('\t\t\tS.U. MOVIE THEATRE!!!!!!!')
    print('\t\t\tBy:SUKESH')

def menu():
    clrscr()
    print('\t\tS.U MOVIE THEATRE WELCOMES YOU!!!')
    print(chr(12)*80)
    while True:
        clrscr()
        print('\t\tS.U. MOVIE THEATRE WELCOMES YOU!!!')
        print(chr(12)*80)
        print('1.Admin')
        print('2.Ticket Booking')
        print('3.See movie list')
        print('4.Signout')
        ch=input('Enter your choice :')
        try:
            ch=int(ch)
            if ch==1:
                passi()
                break
            elif ch==2:
                bookti()
            elif ch==3:
                listfun()
            elif ch==4:
                print('\t\t\tTHANK YOU!!')
                enter=input('PRESS ENTER TO QUIT!!')
                break
            else:
                print ('Invalid option!!')
                enter=input('PRESS ENTER TO CONTINUE!!')
        except:
            print ('Invalid option!!')
            enter=input('PRESS ENTER TO CONTINUE!!')
    
def login():
    clrscr()
    global na
    print('\t\tS.U. MOVIE THEATRE WELCOMES YOU!!!')
    print(chr(12)*80)
    u=input('\n\n\nUsername:')
    try:
        dbh.execute('SELECT pd FROM account WHERE una=?',(u,))
        p1=dbh.fetchone()[0]
        p2=getpass.getpass()
        if p1==p2:
            na=u
            menu()
        else:
            print('\t\tUSERNAME AND PASSWORD DOSENT MATCH')
            enter=input('PRESS ENTER TO CONTINUE!!')
    except:
        print('\t\tUSERNAME DOSENT EXIST')
        enter=input('PRESS ENTER TO CONTINUE!!')

def addfun():
    clrscr()
    print('\t\tS.U. MOVIE THEATRE WELCOMES YOU!!!')
    print(chr(12)*80)
    sn=int(input('Enter screen number:'))
    m=input('Enter movie name:')
    n=int(input('Enter number of tickets:'))
    p=float(input('Enter ticket price:'))
    if n>0 and p>0:
        try:
            dbh.execute('INSERT INTO movie(scre,seu,mona,noot,price) VALUES(?,?,?,?,?)',(int(sn),0,m,int(n),float(p)))
            db.commit()
            print('MOVIE INSERTED!!!!')
            enter=input('PRESS ENTER TO CONTINUE!!')
        except:
            print('UNEXPECTDLY COULDNT ADD MOVIE!!')
            enter=input('PRESS ENTER TO CONTINUE!!')
    else:
        print('INSERT NON ZERO VALUES!!')
        enter=input('PRESS ENTER TO CONTINUE!!')

def listfun():
    clrscr() 
    print('\t\tS.U. MOVIE THEATRE WELCOMES YOU!!!')
    print(chr(12)*80)
    dbh.execute('SELECT * FROM movie')
    l=dbh.fetchall()
    movshow(l)
    
def delfun():
    listfun()
    h=input('ENTER MOVIE NAME TO BE DELETED:')
    try:
        dbh.execute('SELECT * FROM movie WHERE mona=?',(h,))
        check=dbh.fetchone()[0]
        dbh.execute('DELETE FROM movie WHERE mona=?',(h,))
        print('DELETED SUCCESSFULLY!!')
        enter=input('PRESS ENTER TO CONTINUE!!')
    except:
        print('ERROR DELETING!',h,'DOESNT EXISTS!!')
        enter=input('PRESS ENTER TO CONTINUE!!')

def bookti():
    listfun()
    f=0
    k=0
    s=0
    z=0
    y=[]
    mov=input('Enter movie name :')
    n=input('Number of tickets needed:')
    n=int(n)
    if n<1:
        print('MUST BOOK ATLEAST 1 TICKET!!!!!!')
        enter=input('PRESS ENTER TO CONTINUE!!')
        bookti()
    try:
        dbh.execute('SELECT * FROM movie WHERE mona=?',(mov,))
        l=dbh.fetchall() 
        if not l:
            print('THE MOVIE ISNT RUNNING IN THIS THEATRE!!')
            enter=input('PRESS ENTER TO CONTINUE!!')
            bookti()
        for i in l:
            if i[1]+n > i[3]:
                continue
                
            else:
                s=i[1]
                k=i[0]
                z=i[3]
                dbh.execute('UPDATE movie SET seu=? WHERE scre=?',(s+n,k))
                db.commit()
                f=1
                break
        if f == 0:
            print('HOUSE FULL!!')
            enter=input('PRESS ENTER TO CONTINUE!!')
        else:
            clrscr()
            print('\t\t\t BILL')
            print('User:',na)
            print('Movie:',mov)
            print('Screen no:',k)
            print('No of seats:',n)
            print('Your seats are:-')
            for i in range(int(s),int(s)+int(n)):
                print(i)
                y.append(i)
            print('THANK YOU FOR USING S.U. CINEMAS ENJOY YOUR SHOW!')
            print('TAKE A COPY OF THIS TO ENTER THE SCREEN')
            enter=input('PRESS ENTER TO CONTINUE!!')
            dbh.execute('INSERT INTO bill(usna,movna,noti,screno) VALUES(?,?,?,?)',(na,mov,n,k))
            db.commit()    
    except:
        print('THE MOVIE ISNT RUNNING IN THIS THEATRE!!')
        enter=input('PRESS ENTER TO CONTINUE!!')
        
def billist():
    clrscr()
    print('\t\tS.U. MOVIE THEATRE WELCOMES YOU!!!')
    print(chr(12)*80)
    dbh.execute('SELECT * FROM bill')
    l=dbh.fetchall()
    print('{:<20}'.format('USER'),'|','{:<20}'.format('MOVIE NAME'),'|','{:<20}'.format('NO OF TICKETS'),'|','{:<10}'.format('SCREEN NO'))

    for i in l:
        print('{:<20}'.format(i[0]),'|','{:<20}'.format(i[1]),'|','{:<20}'.format(i[2]),'|','{:<10}'.format(i[3]))
        time.sleep(2)
    enter=input('PRESS ENTER TO CONTINUE!!')
    
def adminfun():
    clrscr() 
    print('\t\tS.U. MOVIE THEATRE WELCOMES YOU!!!')                               
    print(chr(12)*80)
    ch=0
    while True:
        clrscr()
        print('\t\tS.U. MOVIE THEATRE WELCOMES YOU!!!')
        print(chr(12)*80)
        print('1.Insert movie')
        print('2.Delete movie')
        print('3.See movie list')
        print('4.See bill list')
        print('5.Back to main menu')
        ch=input('Enter your choice:')
        try:
            ch=int(ch)
            if ch==1:
                addfun()
            elif ch==2:
                delfun()
            elif ch==3:
                listfun()
            elif ch==4:
                billist()
            elif ch==5:
                menu()
                break
            else:
                print('Invalid Option!!')
                enter=input('PRESS ENTER TO CONTINUE!!')
        except:
            print('Invalid Option!!')
            enter=input('PRESS ENTER TO CONTINUE!!')
        
def passi():
    clrscr()
    print('\t\tS.U. MOVIE THEATRE WELCOMES YOU!!!')
    print(chr(12)*80)
    p='sum'
    pa=getpass.getpass()
    if pa == p:
        adminfun()
    else:
        print('WRONG PASSWORD ONLY ADMINS ARE ALLOWED!!')
        enter=input('PRESS ENTER TO CONTINUE!!')

intro()
enter=input('PRESS ENTER TO CONTINUE!!')
clrscr()
print('\t\tS.U. MOVIE THEATRE WELCOMES YOU!!!')
print(chr(12)*80)
while True:
    clrscr()
    print('\t\tS.U. MOVIE THEATRE WELCOMES YOU!!!')
    print(chr(12)*80)
    print('1.New to login')
    print('2.Already have an account')
    print('3.Delete account')
    print('4.Exit')
    ch=input('Enter your choice:')
    try:
        ch=int(ch)
        if ch==1:newuser()
        elif ch==2:login()
        elif ch==3:delacc()
        elif ch==4:
            intro()
            print('\t\t\tTHANK YOU FOR USING THIS APP')
            enter=input('PRESS ENTER TO CONTINUE!!')
            break
        else:
            print('Invalid option')
            enter=input('PRESS ENTER TO CONTINUE!!')
    except:
            print('Invalid option')
            enter=input('PRESS ENTER TO CONTINUE!!')
# Out:
# 			S.U. MOVIE THEATRE!!!!!!!
# 			By:SUKESH
# PRESS ENTER TO CONTINUE!!
# 		S.U. MOVIE THEATRE WELCOMES YOU!!!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		S.U. MOVIE THEATRE WELCOMES YOU!!!
#
# 1.New to login
# 2.Already have an account
# 3.Delete account
# 4.Exit
# Enter your choice: 1
# 		S.U. MOVIE THEATRE WELCOMES YOU!!!
# ENTER USERNAME: sukesh
# ENTER PASSWORD: sukesh03
# YOUR ACCOUNT HAS BEEN CREATED, SO KINDLY LOGIN IN FRONT PAGE
# PRESS ENTER TO CONTINUE!!
# 		S.U. MOVIE THEATRE WELCOMES YOU!!!
#
# 1.New to login
# 2.Already have an account
# 3.Delete account
# 4.Exit
# Enter your choice: 2
# 		S.U. MOVIE THEATRE WELCOMES YOU!!!
# Username: sukesh
#  ········
# 		USERNAME AND PASSWORD DOSENT MATCH
# PRESS ENTER TO CONTINUE!!
# 		S.U. MOVIE THEATRE WELCOMES YOU!!!
#
# 1.New to login
# 2.Already have an account
# ...
